# %% [markdown]
# # Data Exploration - for both original and encoded

# %%
# Load data and then look at distribution
# LOAD DATA HERE
all_digits = []
for digit in range(len(mura_all_data)):
    all_digits.append(mura_all_data[digit][2])

# %%
plt.hist(all_digits)
# Out:
# (array([6903., 7877., 6990., 7141., 6824., 6313., 6876., 7293., 6825.,
#         6958.]),
#  array([0. , 0.9, 1.8, 2.7, 3.6, 4.5, 5.4, 6.3, 7.2, 8.1, 9. ]),
#  <BarContainer object of 10 artists>)
